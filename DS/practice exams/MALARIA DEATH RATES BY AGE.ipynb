# %% [markdown]
# <H4>MALARIA DEATH RATES BY AGE OPEN ANALYSIS</H4>

# %% [markdown]
# <h4>Importing neccessary libraries</h4>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <h4>Importing the dataset</h4>

# %%
malaria_data = pd.read_csv('.csv')
#Displaying the dataset
malaria_data

# %% [markdown]
# <h4>Displaying the first 10 rows on the data</h4>

# %%
malaria_data.head(10) #The head function is used to display the top items of the data

# %% [markdown]
# <h4>Displaying the last 10 rows on the data</h4>

# %%
malaria_data.tail(10) #The tail function is used to display the last items of the data

# %% [markdown]
# <h4>Displaying the shape of the data</h4>

# %%
malaria_data.shape #The shape is an attribute that is used on a pandas dataframe to show the number of rows and columns as seen below
print(f"The Malaria Death rates dataset has {malaria_data.shape[0]} rows and {malaria_data.shape[1]} columns")

# %% [markdown]
# <h4>Displaying the columns in the dataset</h4>

# %%
malaria_data.columns

# %% [markdown]
# <h4>Statistical Information about the dataset</h4>

# %%
malaria_data.describe() #Provides a statistical analysis of the data

# %% [markdown]
# mala
